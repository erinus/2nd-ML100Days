# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum(np.power(y - yp, 2)) / len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 222.423
# The Mean absolute error is 11.607

# %% [markdown]
# # 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# 台灣景氣近年下滑嚴重，政局也漸趨混亂，我本身有中度憂鬱症，感受到環境變動對於社會心理健康的影響，我認為這份資料或許能在一定程度上探討出可作為自殺趨勢評估及預防的指標，對於政府在心理衛教上的推展是件重要的事情。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# [Suicide Rates Overview 1985 to 2016](https://www.kaggle.com/russellyates88/suicide-rates-overview-1985-to-2016)
# 來自 4 個外部資料來源，分別為：
#     - United Nations Development Program. (2018). Human development index (HDI). Retrieved from http://hdr.undp.org/en/indicators/137506
#     - World Bank. (2018). World development indicators: GDP (current US$) by country:1985 to 2016. Retrieved from http://databank.worldbank.org/data/source/world-development-indicators#
#     - [Szamil]. (2017). Suicide in the Twenty-First Century [dataset]. Retrieved from https://www.kaggle.com/szamil/suicide-in-the-twenty-first-century/notebook
#     - World Health Organization. (2018). Suicide prevention. Retrieved from http://www.who.int/mental_health/suicide-prevention/en/
# 3. 蒐集而來的資料型態為何
# CSV with Header
# 4. 這組資料想解決的問題如何評估
# 由主要工作年齡層人數和 GDP 等資料可以算出主要工作收入族群的平均收入，在一定層面上反映整體經濟能力的態勢，然後再由人口數除以主要工作收入族群人數，可計算出工作收入族群中每人平均可能負擔多少人的撫養責任，由此等資料經過分群換算等程序，可概略反映出人口老化壓力、社會扶養壓力、...等趨勢，藉由這些資料對自殺趨勢進行分群評估，或可得出主要工作收入族群對現況壓力產生的自殺趨勢，年輕在學族群對未來不安引發的自殺趨勢，以及老年因照護失能而絕望引發的自殺趨勢。

# %% [markdown]
# # 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 既為自由載客，應將司機分為三大類型，路招、電招及定點排班，不同類型的司機有不同安排方式，路招者需要換算每日移動區間是否貼合熱點路招區域，輔以天氣資料參考（雨天路招發生率較高），電招則依公司來電上車點紀錄對不同時段各區域案件紀錄合適安排電招司機分配區域比例，定點排班則須貼合商業區、大眾運輸接駁、...等熱門排班區進行分配
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     - [政府提供計程車營運分析資料](https://www.iot.gov.tw/Modules/Publication/Publication-Details?node=3598166a-c839-4f0d-8beb-33c093e49de0&id=1115c2d1-49e5-4628-8f0c-35cf9fed44d3)
#     - [過去降雨資料](https://www.cwb.gov.tw/V7/climate/dailyPrecipitation/dP.htm)
#     - [天氣預報資料](https://opendata.cwb.gov.tw/dataset/forecast/F-A0010-001)
#     - 大眾運輸分佈（從 Google 地圖取得）
#     - [捷運各站人流等資料](https://www.metro.taipei/cp.aspx?n=FF31501BEBDD0136)
#     - 本公司各計程車 GPS 路線統計資料
#     - 本公司各案件資料
#     - [動態人口學的背景資料](http://research.sinica.edu.tw/human-dynamics-chan-ta-chien)
# 3. 蒐集而來的資料型態為何
# JSON / CSV / PDF
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 路招：本公司各計程車 GPS 路線統計資料、政府提供計程車營運分析資料及過去降雨資料進行分析，判斷熱點存在區域，並搭配天氣預報指引計程車司機於各時段移往各時段路招熱區，並觀察路招成立案例是否提升
# 電招：透過本公司各電招案件資料進行分區統計，將車輛按各時段統計比例預先指引到各區進行待命，降低客戶因電招所需等待時間過長而取消案件的發生率，並觀察電招成立案例是否提升
# 定點排班：透過大眾運輸分佈、過去降雨資料、政府提供計程車營運分析資料及本公司各案件資料進行分析，找出定點排班輪換率（等待時間低）高的熱點，按各時段不同指引車輛前往排班
